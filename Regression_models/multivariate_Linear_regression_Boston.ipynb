# %% [markdown]
# <a href="https://colab.research.google.com/github/pavanreddy2307/Regression_models/blob/main/Regression_models/multivariate_Linear_regression_Boston.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn import linear_model

# %%
#Load the data
data = pd.read_csv("boston.csv")
data.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
#Create feature and target array from such given data
X = data.drop('medv', axis=1).values
y = data['medv'].values
# Out:
# array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#         4.9800e+00],
#        [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#         9.1400e+00],
#        [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#         4.0300e+00],
#        ...,
#        [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         5.6400e+00],
#        [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#         6.4800e+00],
#        [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         7.8800e+00]])

# %%
X.shape, y.shape
#as y is 1d array convert it into 2d array
# Out:
# ((506, 13), (506,))

# %%
y = y.reshape(-1, 1)

# %%
#Fitting a regression model
reg = linear_model.LinearRegression()
reg.fit(X, y)
# Out:
# LinearRegression()

# %%
#Evaluating the model on training data only
from sklearn.metrics import mean_absolute_error,r2_score,mean_squared_error
y_pred = reg.predict(X)

print(f'MAE = {mean_absolute_error(y, y_pred)}')
print(f'MSE = {mean_squared_error(y, y_pred)}')
print(f'RMSE = {np.sqrt(mean_squared_error(y, y_pred))}')
print(f'R_2 = {r2_score(y, y_pred)}')
# Out:
# MAE = 3.270862810900316
# MSE = 21.894831181729202
# RMSE = 4.679191295697281
# R_2 = 0.7406426641094095

# %%
import seaborn as sns
# plt.figure(figsize=(16, 10))
sns.heatmap(data)
plt.show()

# %%
X_columns=data.loc[:,['rm','dis','b']]
X_columns
# Out:
#         rm     dis       b
# 0    6.575  4.0900  396.90
# 1    6.421  4.9671  396.90
# 2    7.185  4.9671  392.83
# 3    6.998  6.0622  394.63
# 4    7.147  6.0622  396.90
# ..     ...     ...     ...
# 501  6.593  2.4786  391.99
# 502  6.120  2.2875  396.90
# 503  6.976  2.1675  396.90
# 504  6.794  2.3889  393.45
# 505  6.030  2.5050  396.90
#
# [506 rows x 3 columns]

# %%
reg = linear_model.LinearRegression()
reg.fit(X_columns, y)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_absolute_error,r2_score,mean_squared_error
y_pred = reg.predict(X_columns)

print(f'MAE = {mean_absolute_error(y, y_pred)}')
print(f'MSE = {mean_squared_error(y, y_pred)}')
print(f'RMSE = {np.sqrt(mean_squared_error(y, y_pred))}')
print(f'R_2 = {r2_score(y, y_pred)}')
# Out:
# MAE = 4.105920720429522
# MSE = 38.31118575592187
# RMSE = 6.1896030370228
# R_2 = 0.5461811516154977
